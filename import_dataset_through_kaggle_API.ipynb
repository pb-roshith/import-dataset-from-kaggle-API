# %% [markdown]
# <a href="https://colab.research.google.com/github/pb-roshith/import-dataset-from-kaggle-API/blob/main/import_dataset_through_kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d danielcalvoglez/us-tariffs-2025
# Out:
# Dataset URL: https://www.kaggle.com/datasets/danielcalvoglez/us-tariffs-2025
# License(s): other

# %%
from zipfile import ZipFile
dataset='/content/us-tariffs-2025.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print("extracted successfully dude")
# Out:
# extracted successfully dude

# %%
# !ls
# Out:
#  kaggle.json  'Tariff Calculations.csv'
#  sample_data  'Tariff Calculations plus Population.csv'

# %%
import pandas as pd

# Use the 'error_bad_lines=False' argument to skip problematic lines
df = pd.read_csv('/content/Tariff_Calculations.csv', on_bad_lines='skip')

# Or, if you want to see the bad lines:
# df = pd.read_csv('/content/Tariff_Calculations.csv', on_bad_lines='warn')

# Print some info to check for potential issues
print(df.head())  # Display the first few rows
print(df.info())  # Get column data types and non-null counts
# Out:
#                                         Country;US 2024 Deficit;US 2024 Exports;US 2024 Imports (Customs Basis);Trump Tariffs Alleged;Trump Response
# China;-295          401.6;143 545.7;438                                      947.4;67%;34%
# European Union;-235 571.2;370 189.2;605                                      760.4;39%;19%
# Mexico**;-171       809.2;334 041.4;505                                      850.6;34%;17%
# Vietnam;-123        463.0;13  098.2;136                                      561.2;90%;45%
# Taiwan;-73          927.2;42  336.9;116                                      264.0;64%;32%
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 203 entries, ('China;-295', '401.6;143', '545.7;438') to ('Hong Kong;21', '913.5;27', '886.4;5')
# Data columns (total 1 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ...

# %%
df
# Out:
#                                                       Country;US 2024 Deficit;US 2024 Exports;US 2024 Imports (Customs Basis);Trump Tariffs Alleged;Trump Response
# China;-295              401.6;143 545.7;438                                                947.4;67%;34%
# European Union;-235     571.2;370 189.2;605                                                760.4;39%;19%
# Mexico**;-171           809.2;334 041.4;505                                                850.6;34%;17%
# Vietnam;-123            463.0;13  098.2;136                                                561.2;90%;45%
# Taiwan;-73              927.2;42  336.9;116                                                264.0;64%;32%
# ...                                                                                                  ...
# Panama*;10              146.3;10  702.1;555.8;10%;10%                                                NaN
# ...

# %%
df.head()
# Out:
#                                         Country;US 2024 Deficit;US 2024 Exports;US 2024 Imports (Customs Basis);Trump Tariffs Alleged;Trump Response
# China;-295          401.6;143 545.7;438                                      947.4;67%;34%
# European Union;-235 571.2;370 189.2;605                                      760.4;39%;19%
# Mexico**;-171       809.2;334 041.4;505                                      850.6;34%;17%
# Vietnam;-123        463.0;13  098.2;136                                      561.2;90%;45%
# Taiwan;-73          927.2;42  336.9;116                                      264.0;64%;32%
